# %%
from datasets import load_dataset

dataset = load_dataset('openfoodfacts/product-database') 
print(dataset)
# Out:
# Generating food split: 3858359 examples [01:42, 37477.03 examples/s]
# Generating beauty split: 60124 examples [00:00, 122900.39 examples/s]
# DatasetDict({
#     food: Dataset({
#         features: ['additives_n', 'additives_tags', 'allergens_tags', 'brands_tags', 'brands', 'categories', 'categories_tags', 'checkers_tags', 'ciqual_food_name_tags', 'cities_tags', 'code', 'compared_to_category', 'complete', 'completeness', 'correctors_tags', 'countries_tags', 'created_t', 'creator', 'data_quality_errors_tags', 'data_quality_info_tags', 'data_quality_warnings_tags', 'data_sources_tags', 'ecoscore_data', 'ecoscore_grade', 'ecoscore_score', 'ecoscore_tags', 'editors', 'emb_codes_tags', 'emb_codes', 'entry_dates_tags', 'food_groups_tags', 'generic_name', 'images', 'informers_tags', 'ingredients_analysis_tags', 'ingredients_from_palm_oil_n', 'ingredients_n', 'ingredients_original_tags', 'ingredients_percent_analysis', 'ingredients_tags', 'ingredients_text', 'ingredients_with_specified_percent_n', 'ingredients_with_unspecified_percent_n', 'ingredients_without_ciqual_codes_n', 'ingredients_without_ciqual_codes', 'ingredients', 'known_ingredients_n', 'labels_tags', 'labels', 'lang', 'languages_tags', 'last_edit_dates_tags', 'last_editor', 'last_image_t', 'last_modified_by', 'last_modified_t', 'last_updated_t', 'link', 'main_countries_tags', 'manufacturing_places_tags', 'manufacturing_places', 'max_imgid', 'minerals_tags', 'misc_tags', 'new_additives_n', 'no_nutrition_data', 'nova_group', 'nova_groups_tags', 'nova_groups', 'nucleotides_tags', 'nutrient_levels_tags', 'nutriments', 'nutriscore_grade', 'nutriscore_score', 'nutrition_data_per', 'obsolete', 'origins_tags', 'origins', 'owner_fields', 'owner', 'packagings_complete', 'packaging_recycling_tags', 'packaging_shapes_tags', 'packaging_tags', 'packaging_text', 'packaging', 'packagings', 'photographers', 'popularity_key', 'popularity_tags', 'product_name', 'product_quantity_unit', 'product_quantity', 'purchase_places_tags', 'quantity', 'rev', 'scans_n', 'serving_quantity', 'serving_size', 'states_tags', 'stores_tags', 'stores', 'traces_tags', 'unique_scans_n', 'unknown_ingredients_n', 'unknown_nutrients_tags', 'vitamins_tags', 'with_non_nutritive_sweeteners', 'with_sweeteners'],
#         num_rows: 3858359
#     })
#     beauty: Dataset({
#         features: ['additives_n', 'additives_tags', 'allergens_tags', 'brands_tags', 'brands', 'categories', 'categories_tags', 'checkers_tags', 'ciqual_food_name_tags', 'cities_tags', 'code', 'compared_to_category', 'complete', 'completeness', 'correctors_tags', 'countries_tags', 'created_t', 'creator', 'data_quality_errors_tags', 'data_quality_info_tags', 'data_quality_warnings_tags', 'data_sources_tags', 'ecoscore_data', 'ecoscore_grade', 'ecoscore_score', 'ecoscore_tags', 'editors', 'emb_codes_tags', 'emb_codes', 'entry_dates_tags', 'food_groups_tags', 'generic_name', 'images', 'informers_tags', 'ingredients_analysis_tags', 'ingredients_from_palm_oil_n', 'ingredients_n', 'ingredients_original_tags', 'ingredients_percent_analysis', 'ingredients_tags', 'ingredients_text', 'ingredients_with_specified_percent_n', 'ingredients_with_unspecified_percent_n', 'ingredients_without_ciqual_codes_n', 'ingredients_without_ciqual_codes', 'ingredients', 'known_ingredients_n', 'labels_tags', 'labels', 'lang', 'languages_tags', 'last_edit_dates_tags', 'last_editor', 'last_image_t', 'last_modified_by', 'last_modified_t', 'last_updated_t', 'link', 'main_countries_tags', 'manufacturing_places_tags', 'manufacturing_places', 'max_imgid', 'minerals_tags', 'misc_tags', 'new_additives_n', 'no_nutrition_data', 'nova_group', 'nova_groups_tags', 'nova_groups', 'nucleotides_tags', 'nutrient_levels_tags', 'nutriments', 'nutriscore_grade', 'nutriscore_score', 'nutrition_data_per', 'obsolete', 'origins_tags', 'origins', 'owner_fields', 'owner', 'packagings_complete', 'packaging_recycling_tags', 'packaging_shapes_tags', 'packaging_tags', 'packaging_text', 'packaging', 'packagings', 'photographers', 'popularity_key', 'popularity_tags', 'product_name', 'product_quantity_unit', 'product_quantity', 'purchase_places_tags', 'quantity', 'rev', 'scans_n', 'serving_quantity', 'serving_size', 'states_tags', 'stores_tags', 'stores', 'traces_tags', 'unique_scans_n', 'unknown_ingredients_n', 'unknown_nutrients_tags', 'vitamins_tags', 'with_non_nutritive_sweeteners', 'with_sweeteners'],
#         num_rows: 60124
#     })
# })

# %%
for key, value in enumerate(dataset['food'].features):
    print(f"{key}: {value}")
# Out:
# 0: additives_n
# 1: additives_tags
# 2: allergens_tags
# 3: brands_tags
# 4: brands
# 5: categories
# 6: categories_tags
# 7: checkers_tags
# 8: ciqual_food_name_tags
# 9: cities_tags
# 10: code
# 11: compared_to_category
# 12: complete
# 13: completeness
# 14: correctors_tags
# 15: countries_tags
# 16: created_t
# 17: creator
# 18: data_quality_errors_tags
# 19: data_quality_info_tags
# 20: data_quality_warnings_tags
# 21: data_sources_tags
# 22: ecoscore_data
# 23: ecoscore_grade
# 24: ecoscore_score
# 25: ecoscore_tags
# 26: editors
# 27: emb_codes_tags
# 28: emb_codes
# 29: entry_dates_tags
# 30: food_groups_tags
# 31: generic_name
# 32: images
# 33: informers_tags
# 34: ingredients_analysis_tags
# 35: ingredients_from_palm_oil_n
# 36: ingredients_n
# 37: ingredients_original_tags
# 38: ingredients_percent_analysis
# 39: ingredients_tags
# 40: ingredients_text
# 41: ingredients_with_specified_percent_n
# 42: ingredients_with_unspecified_percent_n
# 43: ingredients_without_ciqual_codes_n
# 44: ingredients_without_ciqual_codes
# 45: ingredients
# 46: known_ingredients_n
# 47: labels_tags
# 48: labels
# 49: lang
# 50: languages_tags
# 51: last_edit_dates_tags
# 52: last_editor
# 53: last_image_t
# 54: last_modified_by
# 55: last_modified_t
# 56: last_updated_t
# 57: link
# 58: main_countries_tags
# 59: manufacturing_places_tags
# 60: manufacturing_places
# 61: max_imgid
# 62: minerals_tags
# 63: misc_tags
# 64: new_additives_n
# 65: no_nutrition_data
# 66: nova_group
# 67: nova_groups_tags
# 68: nova_groups
# 69: nucleotides_tags
# 70: nutrient_levels_tags
# 71: nutriments
# 72: nutriscore_grade
# 73: nutriscore_score
# 74: nutrition_data_per
# 75: obsolete
# 76: origins_tags
# 77: origins
# 78: owner_fields
# 79: owner
# 80: packagings_complete
# 81: packaging_recycling_tags
# 82: packaging_shapes_tags
# 83: packaging_tags
# 84: packaging_text
# 85: packaging
# 86: packagings
# 87: photographers
# 88: popularity_key
# 89: popularity_tags
# 90: product_name
# 91: product_quantity_unit
# 92: product_quantity
# 93: purchase_places_tags
# 94: quantity
# 95: rev
# 96: scans_n
# 97: serving_quantity
# 98: serving_size
# 99: states_tags
# 100: stores_tags
# 101: stores
# 102: traces_tags
# 103: unique_scans_n
# 104: unknown_ingredients_n
# 105: unknown_nutrients_tags
# 106: vitamins_tags
# 107: with_non_nutritive_sweeteners
# 108: with_sweeteners

# %%
dataset['food'][0]['images']
# Out:
# [{'key': 'front_fr',
#   'imgid': 1,
#   'rev': 4,
#   'sizes': {'100': {'h': 100, 'w': 75},
#    '200': {'h': 200, 'w': 150},
#    '400': {'h': 400, 'w': 300},
#    'full': {'h': 1200, 'w': 901}},
#   'uploaded_t': None,
#   'uploader': None},
#  {'key': '2',
#   'imgid': None,
#   'rev': None,
#   'sizes': {'100': {'h': 75, 'w': 100},
#    '200': None,
#    '400': {'h': 300, 'w': 400},
#    'full': {'h': 1200, 'w': 1599}},
#   'uploaded_t': 1519297021,
#   'uploader': 'kiliweb'},
#  {'key': '1',
#   'imgid': None,
#   'rev': None,
#   'sizes': {'100': {'h': 100, 'w': 75},
#    '200': None,
#    '400': {'h': 400, 'w': 300},
#    'full': {'h': 1200, 'w': 901}},
#   'uploaded_t': 1519297019,
#   'uploader': 'kiliweb'},
#  {'key': 'nutrition_fr',
#   'imgid': 3,
#   'rev': 15,
#   'sizes': {'100': {'h': 94, 'w': 100},
#    '200': {'h': 188, 'w': 200},
#    '400': {'h': 376, 'w': 400},
#    'full': {'h': 1200, 'w': 1278}},
#   'uploaded_t': None,
#   'uploader': None},
#  {'key': 'ingredients_fr',
#   'imgid': 2,
#   'rev': 10,
#   'sizes': {'100': {'h': 50, 'w': 100},
#    '200': {'h': 100, 'w': 200},
#    '400': {'h': 199, 'w': 400},
#    'full': {'h': 545, 'w': 1095}},
#   'uploaded_t': None,
#   'uploader': None},
#  {'key': '3',
#   'imgid': None,
#   'rev': None,
#   'sizes': {'100': {'h': 94, 'w': 100},
#    '200': None,
#    '400': {'h': 376, 'w': 400},
#    'full': {'h': 1200, 'w': 1278}},
#   'uploaded_t': 1579374831,
#   'uploader': 'kiliweb'}]

# %%
import os
import random
from typing import Dict, List, Any, Optional

class MockDataset:
    def __init__(self, data):
        self.data = data
        self.features = {
            "images": {}, 
            "nutriments": {},
            "product_name": {},
            "nutriscore_grade": {},
            "ecoscore_grade": {},
            "code": {},
            "quantity": {}
        } 

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]
    
food_dataset = MockDataset(dataset['food'])

# %%
class SimpleNutritionalConfig:
    """
    Minimal configuration for extracting nutritional facts.
    """
    def __init__(self,
                 output_dir: str = "simple_nutri_data",
                 nutritional_fields: List[str] = ['energy-kcal_100g', 'fat_100g', 'proteins_100g'],
                 split_ratio: float = 0.8, # Simple train/test split
                 seed: int = 42
                ):
        self.output_dir = output_dir
        self.nutritional_fields = nutritional_fields
        self.split_ratio = split_ratio
        self.seed = seed

class NutritionalFactEntry:
    """
    Represents a single entry for nutritional fact extraction (simplified).
    """
    def __init__(self,
                 code: str,
                 product_name: str,
                 image_url: str, # We'll just store the URL for simplicity
                 ground_truth: Dict[str, float]):
        self.code = code
        self.product_name = product_name
        self.image_url = image_url
        self.ground_truth = ground_truth

    def __repr__(self):
        return (f"NutritionalFactEntry(code='{self.code}', product='{self.product_name}', "
                f"image_url='{self.image_url}', ground_truth={self.ground_truth})")

def prepare_simple_nutritional_dataset(
    dataset: Any,
    config: SimpleNutritionalConfig
) -> Dict[str, List[NutritionalFactEntry]]:
    """
    Prepares a simplified dataset for nutritional fact extraction.
    Only takes a few samples and features.
    """
    random.seed(config.seed)
    all_entries: List[NutritionalFactEntry] = []

    print(f"Processing {len(dataset)} simulated entries...")

    for i, item in enumerate(dataset):

        if i == 1000:
            break
  
        image_url = item.get('images'," sample url ")

        ground_truth_nutrients = item.get('nutriments', {})
        

        # 3. Create NutritionalFactEntry
        entry = NutritionalFactEntry(
            code=item.get('code', f"no_code_{i}"),
            product_name=item.get('product_name', 'Unknown Product'),
            image_url=image_url, # We're just storing the URL for this simplified version
            ground_truth=ground_truth_nutrients
        )
        all_entries.append(entry)

    print(f"Found {len(all_entries)} valid entries for processing.")

    # 4. Simple Data Splitting (Train/Test)
    random.shuffle(all_entries)
    train_size = int(len(all_entries) * config.split_ratio)

    splits = {
        'train': all_entries[:train_size],
        'test': all_entries[train_size:]
    }

    print(f"Dataset split: Train={len(splits['train'])}, Test={len(splits['test'])}")

    return splits

# --- Example Usage ---
if __name__ == "__main__":
    # Define your simplified configuration
    simple_config = SimpleNutritionalConfig(
        output_dir="my_nutri_dataset", 
        nutritional_fields=['energy-kcal_100g', 'fat_100g'], 
        split_ratio=0.7 # 70% train, 30% test
    )

    # Prepare the dataset splits
    prepared_data = prepare_simple_nutritional_dataset(food_dataset, simple_config)

    # Access the splits
    train_set = prepared_data['train']
    test_set = prepared_data['test']

    print("\n--- Sample from Training Data ---")
    for entry in train_set:
        print(entry)
        print("-" * 20)

    print("\n--- Sample from Test Data ---")
    for entry in test_set:
        print(entry)
        print("-" * 20)
# Out:
# Processing 3858359 simulated entries...
# Found 1000 valid entries for processing.
# Dataset split: Train=700, Test=300
#
# --- Sample from Training Data ---
# NutritionalFactEntry(code='0009542018276', product='[{'lang': 'main', 'text': 'Milk Chocolate Elf'}, {'lang': 'en', 'text': 'Milk Chocolate Elf'}]', image_url='[{'key': 'front_en', 'imgid': 1, 'rev': 5, 'sizes': {'100': {'h': 36, 'w': 100}, '200': {'h': 71, 'w': 200}, '400': {'h': 143, 'w': 400}, 'full': {'h': 344, 'w': 963}}, 'uploaded_t': None, 'uploader': None}, {'key': '1', 'imgid': None, 'rev': None, 'sizes': {'100': {'h': 36, 'w': 100}, '200': None, '400': {'h': 143, 'w': 400}, 'full': {'h': 344, 'w': 963}}, 'uploaded_t': 1670988405, 'uploader': 'kiliweb'}]', ground_truth=[{'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'cholesterol', 'value': 20.0, '100g': 0.05000000074505806, 'serving': 0.019999999552965164, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 2.0, '100g': 5.0, 'serving': 2.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 220.0, '100g': 550.0, 'serving': 220.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 220.0, '100g': 2300.0, 'serving': 920.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'iron', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'trans-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value': 0.11175999790430069, '100g': 0.27900001406669617, 'serving': 0.11175999790430069, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fat', 'value': 36.0, '100g': 90.0, 'serving': 36.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'potassium', 'value': 298.0, '100g': 0.7450000047683716, 'serving': 0.2980000078678131, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nutrition-score-fr', 'value': None, '100g': 32.0, 'serving': None, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 0.2793999910354614, '100g': 0.6980000138282776, 'serving': 0.2793999910354614, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'saturated-fat', 'value': 22.0, '100g': 55.0, 'serving': 22.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 6.0, '100g': 15.0, 'serving': 6.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'calcium', 'value': 200.0, '100g': 0.5, 'serving': 0.20000000298023224, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 50.0, '100g': 125.0, 'serving': 50.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 55.0, '100g': 138.0, 'serving': 55.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-a', 'value': 7.500000356230885e-05, '100g': 1.86999998819104e-10, 'serving': 7.499999926663392e-11, 'unit': 'µg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, { ...
# --------------------
# NutritionalFactEntry(code='0008982000216', product='[{'lang': 'main', 'text': 'Cracker Crisps Sesame Mini Crackers'}, {'lang': 'en', 'text': 'Cracker Crisps Sesame Mini Crackers'}]', image_url='[]', ground_truth=[{'name': 'fat', 'value': 21.43000030517578, '100g': 75.5999984741211, 'serving': 21.43000030517578, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 10.710000038146973, '100g': 37.79999923706055, 'serving': 10.710000038146973, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-a', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'µg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 3.569999933242798, '100g': 12.600000381469727, 'serving': 3.569999933242798, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'trans-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 4.0, 'serving': 4.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 1250.0, '100g': 4.409999847412109, 'serving': 1.25, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'saturated-fat', 'value': 10.710000038146973, '100g': 37.79999923706055, 'serving': 10.710000038146973, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 64.29000091552734, '100g': 227.0, 'serving': 64.29000091552734, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 3.5999999046325684, '100g': 12.699999809265137, 'serving': 3.5999999046325684, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 257.1600036621094, '100g': 3800.0, 'serving': 1076.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'iron', 'value': 2.569999933242798, '100g': 0.009069999679923058, 'serving': 0.002570000011473894, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'calcium', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value': 500.0, '100g': 1.7599999904632568, 'serving': 0.5, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'cholesterol', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 257.1600036621094, '100g': 907.0, 'serving': 257.1600036621094, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, { ...
# --------------------
# NutritionalFactEntry(code='0009800057146', product='[{'lang': 'main', 'text': 'Flavored Mints, Spearmint Mix'}, {'lang': 'en', 'text': 'Flavored Mints, Spearmint Mix'}]', image_url='[]', ground_truth=[{'name': 'sugars', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 388.0, '100g': 388.0, 'serving': 1.899999976158142, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 388.0, '100g': 1623.0, 'serving': 7.949999809265137, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 4.0, 'serving': 4.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}])
# --------------------
# NutritionalFactEntry(code='0009800200238', product='[{'lang': 'main', 'text': 'Fine Assorted Confection Chocolates'}, {'lang': 'en', 'text': 'Fine Assorted Confection Chocolates'}]', image_url='[]', ground_truth=[{'name': 'calcium', 'value': 100.0, '100g': 0.25, 'serving': 0.10000000149011612, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 5.0, '100g': 12.5, 'serving': 5.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 220.0, '100g': 0.550000011920929, 'serving': 0.2199999988079071, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 37.5, '100g': 93.80000305175781, 'serving': 37.5, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'saturated-fat', 'value': 20.0, '100g': 50.0, 'serving': 20.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'trans-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-a', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'µg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'iron', 'value': 2.700000047683716, '100g': 0.006750000175088644, 'serving': 0.0027000000700354576, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 17.69301414489746, 'serving': 17.69301414489746, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 47.5, '100g': 119.0, 'serving': 47.5, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 5.882352828979492, 'serving': 5.882352828979492, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 4.0, 'serving': 4.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'cholesterol', 'value': 12.0, '100g': 0.029999999329447746, 'serving': 0.012000000104308128, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 190.0, '100g': 1990.0, 'serving': 795.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 190.0, '100g': 475.0, 'serving': 190.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fat', 'value': 42.5, '100g': 106.0, 'serving': 42.5, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value':
 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 6.699999809265137, '100g': 44.70000076293945, 'serving': 6.699999809265137, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 66.66999816894531, '100g': 444.0, 'serving': 66.66999816894531, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 4.0, 'serving': 4.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 0.0906808003783226, 'serving': 0.0906808003783226, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 26.670000076293945, '100g': 178.0, 'serving': 26.670000076293945, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'calcium', 'value': 133.0, '100g': 0.8870000243186951, 'serving': 0.13300000131130219, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0906808003783226, 'serving': 0.0906808003783226, 'unit': None, 'prepared_va ...
# --------------------
# NutritionalFactEntry(code='0009125001619', product='[{'lang': 'main', 'text': "Fall Hornin' pumpkin ale"}, {'lang': 'nl', 'text': "Fall Hornin' pumpkin ale"}]', image_url='[{'key': 'front_nl', 'imgid': 2, 'rev': 5, 'sizes': {'100': {'h': 100, 'w': 29}, '200': {'h': 200, 'w': 59}, '400': {'h': 400, 'w': 117}, 'full': {'h': 3264, 'w': 955}}, 'uploaded_t': None, 'uploader': None}, {'key': '2', 'imgid': None, 'rev': None, 'sizes': {'100': {'h': 100, 'w': 75}, '200': None, '400': {'h': 400, 'w': 300}, 'full': {'h': 3264, 'w': 2448}}, 'uploaded_t': 1478281814, 'uploader': 'aleene'}, {'key': '1', 'imgid': None, 'rev': None, 'sizes': {'100': {'h': 100, 'w': 75}, '200': None, '400': {'h': 400, 'w': 300}, 'full': {'h': 3264, 'w': 2448}}, 'uploaded_t': 1478281779, 'uploader': 'aleene'}]', ground_truth=None)
# --------------------
# NutritionalFactEntry(code='0000946909078', product='[{'lang': 'main', 'text': 'Augason Farms, Vital Wheat Gluten'}, {'lang': 'en', 'text': 'Augason Farms, Vital Wheat Gluten'}]', image_url='[]', ground_truth=[{'name': 'energy', 'value': 333.0, '100g': 1393.0, 'serving': 41.79999923706055, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'trans-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 333.0, '100g': 333.0, 'serving': 9.989999771118164, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'iron', 'value': 12.0, '100g': 0.012000000104308128, 'serving': 0.0003600000054575503, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 66.66999816894531, '100g': 66.66999816894531, 'serving': 2.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'cholesterol', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'saturated-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-a', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'IU', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'calcium', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nutrition-score-fr', 'value': None, '100g': -3.0, 'serving': None, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}])
# --------------------
# NutritionalFactEntry(code='0009542020736', product='[{'lang': 'main', 'text': 'Dark Chocolate'}, {'lang': 'en', 'text': 'Dark Chocolate'}]', image_url='[]', ground_truth=[{'name': 'carbohydrates', 'value': 55.0, '100g': 138.0, 'serving': 55.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 4.0, 'serving': 4.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 52.5, '100g': 131.0, 'serving': 52.5, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'calcium', 'value': 50.0, '100g': 0.125, 'serving': 0.05000000074505806, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'trans-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-a', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'µg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'iron', 'value': 2.700000047683716, '100g': 0.006750000175088644, 'serving': 0.0027000000700354576, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'saturated-fat', 'value': 17.5, '100g': 43.79999923706055, 'serving': 17.5, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 2.5, '100g': 6.25, 'serving': 2.5, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 375.0, '100g': 0.9380000233650208, 'serving': 0.375, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value': 150.0, '100g': 0.375, 'serving': 0.15000000596046448, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 220.0, '100g': 2300.0, 'serving': 920.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nutrition-score-fr', 'value': None, '100g': 32.0, 'serving': None, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'cholesterol', 'value': 12.0, '100g': 0.029999999329447746, 'serving': 0.012000000104308128, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 5.0, '100g': 12.5, 'serving': 5.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 220.0, '100g': 550.0, 'serving': 220.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fat', 'value': 30.0, '100g': 75.0, 'serving': 30.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}])
# --------------------
# NutritionalFactEntry(code='0008346720019', product='[{'lang': 'main', 'text': 'Slimfast, 10 Day Slim Down Meal Replacement Shake, Creamy Milk Chocolate'}, {'lang': 'en', 'text': 'Slimfast, 10 Day Slim Down Meal Replacement Shake, Creamy Milk Chocolate'}]', image_url='[{'key': 'front_en', 'imgid': 1, 'rev': 4, 'sizes': {'100': {'h': 58, 'w': 100}, '200': {'h': 115, 'w': 200}, '400': {'h': 230, 'w': 400}, 'full': {'h': 1153, 'w': 2002}}, 'uploaded_t': None, 'uploader': None}, {'key': '1', 'imgid': None, 'rev': None, 'sizes': {'100': {'h':
0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 4.0, 'serving': 4.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 639.0, '100g': 2674.0, 'serving': 963.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 5.559999942779541, '100g': 5.559999942779541, 'serving': 2.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'cholesterol', 'value': 14.0, '100g': 0.014000000432133675, 'serving': 0.005040000192821026, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-a', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'IU', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 36.11000061035156, '100g': 36.11000061035156, 'serving': 13.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'calcium', 'value': 56.0, '100g': 0.0560000017285347, 'serving': 0.02019999921321869, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates ...
# --------------------
# NutritionalFactEntry(code='0000197571406', product='[{'lang': 'main', 'text': 'Puppodums'}, {'lang': 'en', 'text': 'Puppodums'}]', image_url='[]', ground_truth=[{'name': 'sugars', 'value': 0.6000000238418579, '100g': 0.6000000238418579, 'serving': 0.6000000238418579, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 45.70000076293945, '100g': 45.70000076293945, 'serving': 45.70000076293945, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 3.0, 'serving': 3.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 6.0960001945495605, '100g': 6.099999904632568, 'serving': 6.0960001945495605, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 10.100000381469727, '100g': 10.100000381469727, 'serving': 10.100000381469727, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 21.899999618530273, '100g': 21.899999618530273, 'serving': 21.899999618530273, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fat', 'value': 0.30000001192092896, '100g': 0.30000001192092896, 'serving': 0.30000001192092896, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 182.8000030517578, '100g': 183.0, 'serving': 182.8000030517578, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value': 2.4384000301361084, '100g': 2.440000057220459, 'serving': 2.4384000301361084, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 182.8000030517578, '100g': 765.0, 'serving': 765.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}])
# --------------------
# NutritionalFactEntry(code='0000790110002', product='[{'lang': 'main', 'text': 'Emojeez, Gummies, Assorted Fruits'}, {'lang': 'en', 'text': 'Emojeez, Gummies, Assorted Fruits'}]', image_url='[]', ground_truth=[{'name': 'iron', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'trans-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'salt', 'value': 30.0, '100g': 0.029999999329447746, 'serving': 0.012000000104308128, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'saturated-fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fiber', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sodium', 'value': 12.0, '100g': 0.012000000104308128, 'serving': 0.004800000227987766, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fat', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy', 'value': 275.0, '100g': 1151.0, 'serving': 460.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nova-group', 'value': None, '100g': 4.0, 'serving': 4.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'energy-kcal', 'value': 275.0, '100g': 275.0, 'serving': 110.0, 'unit': 'kcal', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'cholesterol', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'proteins', 'value': 5.0, '100g': 5.0, 'serving': 2.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'sugars', 'value': 40.0, '100g': 40.0, 'serving': 16.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-a', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'IU', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'vitamin-c', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-nuts-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'calcium', 'value': 0.0, '100g': 0.0, 'serving': 0.0, 'unit': 'mg', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'carbohydrates', 'value': 67.5, '100g': 67.5, 'serving': 27.0, 'unit': 'g', 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'fruits-vegetables-legumes-estimate-from-ingredients', 'value': None, '100g': 0.0, 'serving': 0.0, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}, {'name': 'nutrition-score-fr', 'value': None, '100g': 14.0, 'serving': None, 'unit': None, 'prepared_value': None, 'prepared_100g': None, 'prepared_serving': None, 'prepared_unit': None}])
# --------------------
# NutritionalFactEntry(code='0009531112763', product='[]', image_url='[{'key': '1', 'imgid': None, 'rev': None, 'sizes': {'100': {'h': 100, 'w': 71}, '200': None, '400': {'h': 400, 'w': 282}, 'full': {'h': 1418, 'w': 1000}}, 'uploaded_t': 1533760123, 'uploader': 'date-limite-app'}, {'key': 'front_en', 'imgid': 1, 'rev': 3, 'sizes': {'100': {'h': 100, 'w': 48}, '200': {'h': 200, 'w': 96}, '400': {'h': 400, 'w': 192}, 'full': {'h': 1368, 'w': 656}}, 'uploaded_t': None, 'uploader': None}]', ground_truth=None)
# --------------------
